# %% [raw]
# Description
# The given dataset 'cust_rating' has 3 columns i.e 'rating', ' food_rating', 'service_rating'. Create a new variable 'avg_rating'.

# %%
import pandas as pd
cust_rating = pd.read_csv('https://query.data.world/s/ILc-P4llUraMaYN6N6Bdw7p6kUvHnj')

# %%
# cust_rating['avg_rating'] = round(#Type your code here.)

# print(cust_rating.head(10))

# %%
cust_rating.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
cust_rating['avg_rating'] = round((cust_rating['rating'] + cust_rating['food_rating']+cust_rating['service_rating'])/3,1)

# %%
cust_rating.head(10)
# Out:
#   userID  placeID  rating  food_rating  service_rating  avg_rating
# 0  U1077   135085       2            2               2         2.0
# 1  U1077   135038       2            2               1         1.7
# 2  U1077   132825       2            2               2         2.0
# 3  U1077   135060       1            2               2         1.7
# 4  U1068   135104       1            1               2         1.3
# 5  U1068   132740       0            0               0         0.0
# 6  U1068   132663       1            1               1         1.0
# 7  U1068   132732       0            0               0         0.0
# 8  U1068   132630       1            1               1         1.0
# 9  U1067   132584       2            2               2         2.0

# %%
import math
cust_rating.avg_rating = cust_rating.avg_rating.apply(lambda x:round(math.ceil(x)),1)

# %%
cust_rating.head(10)
# Out:
#   userID  placeID  rating  food_rating  service_rating  avg_rating
# 0  U1077   135085       2            2               2           2
# 1  U1077   135038       2            2               1           2
# 2  U1077   132825       2            2               2           2
# 3  U1077   135060       1            2               2           2
# 4  U1068   135104       1            1               2           2
# 5  U1068   132740       0            0               0           0
# 6  U1068   132663       1            1               1           1
# 7  U1068   132732       0            0               0           0
# 8  U1068   132630       1            1               1           1
# 9  U1067   132584       2            2               2           2

# %% [markdown]
# ## Quiz Question

# %%
df_cric = pd.read_csv('odi-batting.csv')

# %%
df_cric.head()
# Out:
#        Country            Player  Runs   MatchDate Weekday  \
# 0  Afghanistan  Mohammad Shahzad   118  16-02-2010     Tue
# 1  Afghanistan  Mohammad Shahzad   110  01-09-2009     Tue
# 2  Afghanistan  Mohammad Shahzad   100  16-08-2010     Mon
# 3  Afghanistan  Mohammad Shahzad    82  10-07-2010     Sat
# 4  Afghanistan  Mohammad Shahzad    57  01-07-2010     Thu
#
#                   Ground       Versus  Balls
# 0     Sharjah CA Stadium       Canada    121
# 1             VRA Ground  Netherlands    111
# 2  Cambusdoon New Ground     Scotland     72
# 3            Hazelaarweg  Netherlands    108
# 4    Sportpark Westvliet       Canada     57

# %%
df_cric['century'] = df_cric['Runs'] >= 100

# %%
df_cric.head()
# Out:
#        Country            Player  Runs   MatchDate Weekday  \
# 0  Afghanistan  Mohammad Shahzad   118  16-02-2010     Tue
# 1  Afghanistan  Mohammad Shahzad   110  01-09-2009     Tue
# 2  Afghanistan  Mohammad Shahzad   100  16-08-2010     Mon
# 3  Afghanistan  Mohammad Shahzad    82  10-07-2010     Sat
# 4  Afghanistan  Mohammad Shahzad    57  01-07-2010     Thu
#
#                   Ground       Versus  Balls  century
# 0     Sharjah CA Stadium       Canada    121     True
# 1             VRA Ground  Netherlands    111     True
# 2  Cambusdoon New Ground     Scotland     72     True
# 3            Hazelaarweg  Netherlands    108    False
# 4    Sportpark Westvliet       Canada     57    False

# %%
df_cric.groupby(by='Player')['century'].sum().sort_values(ascending = False)
# Out:
# Player
# Sachin R Tendulkar            48.0
# Ricky T Ponting               30.0
# Sanath T Jayasuriya           28.0
# Sourav C Ganguly              22.0
# Herschelle H Gibbs            21.0
# Saeed Anwar                   20.0
# Brian C Lara                  19.0
# Christopher H Gayle           19.0
# Mark E Waugh                  18.0
# Desmond L Haynes              17.0
# Jacques H Kallis              17.0
# Nathan J Astle                16.0
# Adam C Gilchrist              16.0
# D P Mahela Jayawardene        15.0
# Mohammad Yousuf               15.0
# Virender Sehwag               14.0
# Gary Kirsten                  13.0
# Yuvraj Singh                  13.0
# Marcus E Trescothick          12.0
# Rahul Dravid                  12.0
# W Upul Tharanga               12.0
# Pinnaduwage A de Silva        11.0
# Cuthbert Gordon Greenidge     11.0
# Kumar C Sangakkara            11.0
# Abraham B de Villiers         11.0
# Marvan S Atapattu             11.0
# ...

# %%
df_cric['strikerate'] = df_cric['Runs']/df_cric['Balls']

# %%
df_cric_cen = df_cric[df_cric['century']==True]

# %%
df_cric_cen.sort_values(by=['strikerate'], ascending=False)
# Out:
#             Country                     Player  Runs   MatchDate Weekday  \
# 28157      Pakistan              Shahid Afridi   102  04-10-1996     Fri
# 28158      Pakistan              Shahid Afridi   102  15-04-2005     Fri
# 34446  South Africa             Mark V Boucher   147  20-09-2006     Wed
# 28153      Pakistan              Shahid Afridi   124  21-06-2010     Mon
# 36753     Sri Lanka        Sanath T Jayasuriya   134  02-04-1996     Tue
# 2872      Australia             Shane R Watson   185  11-04-2011     Mon
# 41927   West Indies               Brian C Lara   117  09-10-1999     Sat
# 19704       Ireland            Kevin J O'Brien   113  02-03-2011     Wed
# 14912         India               Yuvraj Singh   138  14-11-2008     Fri
# 34657  South Africa      Abraham B de Villiers   102  27-02-2010     Sat
# 15152         India            Virender Sehwag   125  11-03-2009     Wed
# 14615         India        Mohammad Azharuddin   108  17-12-1988     Sat
# ...

# %%
df_cric_cen.columns
# Out:
# Index(['Country', 'Player', 'Runs', 'MatchDate', 'Weekday', 'Ground', 'Versus',
#        'Balls', 'century', 'strikerate'],
#       dtype='object')

# %%
df_cric_cen['date'] = pd.to_datetime(df_cric_cen['MatchDate'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_cric_cen.columns
# Out:
# Index(['Country', 'Player', 'Runs', 'MatchDate', 'Weekday', 'Ground', 'Versus',
#        'Balls', 'century', 'strikerate', 'date'],
#       dtype='object')

# %%
def extractYear(x):
    return x.year

# %%
df_cric_cen['year'] = df_cric_cen['date'].apply(extractYear)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_cric_cen.year
# Out:
# 0        2010
# 1        2009
# 2        2010
# 62       2010
# 87       2010
# 138      2006
# 139      1998
# 140      2005
# 141      2003
# 142      2007
# 143      2002
# 144      2009
# 145      1998
# 146      2006
# 147      2008
# 148      1996
# 149      2002
# 150      2000
# 151      2005
# 152      2003
# 153      2007
# 154      2007
# 155      2009
# 156      2005
# 157      2003
# 158      2007
# 159      2010
# 160      2003
# 161      2007
# 162      2011
#          ...
# 47306    1998
# 47307    1998
# 47474    2010
# 47475    2011
# 47476    2010
# 47477    2009
# 47478    2011
# 47479    2011
# 47594    2007
# 47595    2009
# 47712    2009
# 47713    2009
# 47714    2009
# 48084    1999
# 48085    2001
# 48086    2004
# 48310    2006
# 48493    2000
# 48494    1998
# 48562    2003
# 48563    1998
# 48636    1999
# 48637    1999
# 48638    1998
# 48639    1999
# 48682    1987
# 48737    2001
# 49101    2009
# 49208    2004
# 49237    2003
# ...

# %%
# pd.DataFrame(df_cric_cen.groupby(by=['Country','year']))['century'].sum()

# %%
df_temp = pd.DataFrame(df_cric_cen.groupby(by=['Country','year'])['century'].sum())

# %%
df_temp.to_csv('a.csv')

# %% [raw]
# Extracting Day From a Date
# Description
# The given dataset 'order' has a variable 'Order_Date' with the dates of purchase.
# Create a new variable 'day' which will contain the day from the date at variable Order_Date.

# %%
import pandas as pd
order = pd.read_csv('https://query.data.world/s/3hIAtsCE7vYkPEL-O5DyWJAeS5Af-7')
order['Order_Date'] = pd.to_datetime(order['Order_Date'])

# %%
order['day'] = order['Order_Date'].apply(lambda x: x.day)

order.head(10)
# Out:
#    Order_ID Order_Date Order_Priority  Ord_id  day
# 0         3 2010-10-13            LOW   Ord_1   13
# 1       293 2012-01-10           HIGH   Ord_2   10
# 2       483 2011-10-07           HIGH   Ord_3    7
# 3       515 2010-08-28  NOT SPECIFIED   Ord_4   28
# 4       613 2011-06-17           HIGH   Ord_5   17
# 5       643 2011-03-24           HIGH   Ord_6   24
# 6       678 2010-02-26            LOW   Ord_7   26
# 7       807 2010-11-23         MEDIUM   Ord_8   23
# 8       868 2012-08-06  NOT SPECIFIED   Ord_9    6
# 9       933 2012-04-08  NOT SPECIFIED  Ord_10    8

# %%
order.head(10)
# Out:
#    Order_ID Order_Date Order_Priority  Ord_id  day
# 0         3 2010-10-13            LOW   Ord_1   13
# 1       293 2012-01-10           HIGH   Ord_2   10
# 2       483 2011-10-07           HIGH   Ord_3    7
# 3       515 2010-08-28  NOT SPECIFIED   Ord_4   28
# 4       613 2011-06-17           HIGH   Ord_5   17
# 5       643 2011-03-24           HIGH   Ord_6   24
# 6       678 2010-02-26            LOW   Ord_7   26
# 7       807 2010-11-23         MEDIUM   Ord_8   23
# 8       868 2012-08-06  NOT SPECIFIED   Ord_9    6
# 9       933 2012-04-08  NOT SPECIFIED  Ord_10    8

# %% [markdown]
# ## Quiz Question

# %%
df_upgrad = pd.read_csv('grades.csv')

# %%
df_upgrad.head(10)
# Out:
#                                           submission         submit_time  day  \
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44... 2017-01-03 20:28:52    3
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4c... 2017-01-03 20:18:21    3
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-43... 2017-01-03 22:37:08    3
# 3  https://ckd.upgrad.com/UpGrad/002fc912-faa1-49... 2017-01-02 21:43:19    2
# 4  https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f... 2017-01-03 15:27:49    3
# 5  https://ckd.upgrad.com/UpGrad/0ab308ab-2b3a-4c... 2017-01-04 02:43:46    4
# 6  https://ckd.upgrad.com/UpGrad/ba2c249c-dac8-46... 2017-01-03 23:41:25    3
# 7  https://ckd.upgrad.com/UpGrad/d8969806-6760-44... 2017-01-09 23:49:09    9
# 8  https://ckd.upgrad.com/UpGrad/5ff1d0ab-816b-48... 2016-12-30 14:14:17   30
# 9  https://ckd.upgrad.com/UpGrad/0d507851-d102-47... 2017-01-03 21:18:04    3
#
#    month  year  hour  minutes format        roll  after_dd1
# ...

# %%
df_upgrad.submit_time = pd.to_datetime(df_upgrad.submit_time)

# %%
 date, day, month, year, hour, and minutes

# %%
df_upgrad['day'] = df_upgrad['submit_time'].apply(lambda x:x.day)

# %%
df_upgrad['month'] = df_upgrad['submit_time'].apply(lambda x:x.month)

# %%
df_upgrad['year'] = df_upgrad['submit_time'].apply(lambda x:x.year)

# %%
df_upgrad['hour'] = df_upgrad['submit_time'].apply(lambda x:x.hour)

# %%
df_upgrad['minutes'] = df_upgrad['submit_time'].apply(lambda x:x.minute)

# %%
df_upgrad.submission[0]
# Out:
# 'https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip'

# %%
def submission_format(x):
    return x.split(".")[-1]

# %%
def student_rollnumber(x):
    return a.split("/")[-1].split(".")[0]

# %%
a = 'https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip'
splits = a.split(".")
submission_format = a.split(".")[-1]
print(submission_format)
a.split("/")[-1].split(".")[0]
# Out:
# zip
# https://ckd
# 'DDA1610095'

# %%
df_upgrad['format'] = df_upgrad['submission'].apply(submission_format)

# %%
df_upgrad['roll'] = df_upgrad['submission'].apply(student_rollnumber)

# %%
df_upgrad.format.value_counts()
# Out:
# zip    189
# R        7
# 7z       2
# Name: format, dtype: int64

# %%
type(df_upgrad.submit_time[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
import datetime
deadline1 = datetime.datetime(2017, 1, 7, 23, 59)
deadline2 = datetime.datetime(2017, 1, 9, 23, 59)
print(deadline1, type(deadline1))
print(deadline2, type(deadline2))
# Out:
# 2017-01-07 23:59:00 <class 'datetime.datetime'>
# 2017-01-09 23:59:00 <class 'datetime.datetime'>

# %%
def sub_after_first_deadline(x):
    return pd.to_datetime(x) >= deadline1

# %%
pd.to_datetime(deadline1)
# Out:
# Timestamp('2017-01-07 23:59:00')

# %%
df_upgrad.submit_time[7] > deadline1
# Out:
# True

# %%
df_upgrad['after_dd1'] = df_upgrad['submit_time'].apply(sub_after_first_deadline)

# %%
(df_upgrad[df_upgrad.after_dd1==True]).shape
# Out:
# (29, 10)

# %%
df_upgrad.submit_time[7].date()
# Out:
# datetime.date(2017, 1, 9)

# %%
d='2015-01-08 22:44:09' 
date=pd.to_datetime(d).time(formatrint(date)
# Out:
# 22:44:09

# %%
df_upgrad['date'] = df_upgrad.submit_time.apply(lambda x:x.date())

# %%
df_upgrad.head()
# Out:
#                                           submission         submit_time  day  \
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44... 2017-01-03 20:28:52    3
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4c... 2017-01-03 20:18:21    3
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-43... 2017-01-03 22:37:08    3
# 3  https://ckd.upgrad.com/UpGrad/002fc912-faa1-49... 2017-01-02 21:43:19    2
# 4  https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f... 2017-01-03 15:27:49    3
#
#    month  year  hour  minutes format        roll  after_dd1        date
# 0      1  2017    20       28    zip  DDA1610095      False  2017-01-03
# 1      1  2017    20       18    zip  DDA1610095      False  2017-01-03
# 2      1  2017    22       37    zip  DDA1610095      False  2017-01-03
# 3      1  2017    21       43    zip  DDA1610095      False  2017-01-02
# 4      1  2017    15       27    zip  DDA1610095      False  2017-01-03

# %%
# df_upgrad.groupby(by=['date']).value_counts()

# %%
df_upgrad.date.value_counts()
# Out:
# 2017-01-03    120
# 2017-01-09     21
# 2017-01-02     14
# 2017-01-04     12
# 2016-12-30      6
# 2017-01-01      6
# 2017-01-10      3
# 2017-01-08      3
# 2017-01-07      2
# 2016-12-29      2
# 2016-12-28      2
# 2017-02-03      1
# 2016-12-21      1
# 2017-01-17      1
# 2017-01-06      1
# 2016-12-31      1
# 2016-11-19      1
# 2016-12-19      1
# Name: date, dtype: int64

# %%
df_upgrad.hour.value_counts()
# Out:
# 23    66
# 21    27
# 22    24
# 20    16
# 0     10
# 1      8
# 18     6
# 14     6
# 13     6
# 17     4
# 15     4
# 3      3
# 10     3
# 12     3
# 4      2
# 19     2
# 2      2
# 16     2
# 11     1
# 9      1
# 8      1
# 6      1
# Name: hour, dtype: int64
